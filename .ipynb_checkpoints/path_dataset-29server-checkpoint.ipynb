# %%
import os
import pandas as pd
import numpy as np
import glob, warnings
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Train, validation Set

# %%
DF = pd.read_csv('/media/tohn/HDD/rheology2023/filesMSDT_G/datasetMSDT_train_valid.csv')
DF_TRAIN = DF[DF['subset']=='train'].reset_index(drop=True)
print(DF_TRAIN.shape)
DF_VAL = DF[DF['subset']=='valid'].reset_index(drop=True)
print(DF_VAL.shape)
# Out:
# (19778, 9)
# (3857, 9)

# %%
DF
# Out:
#        Unnamed: 0.1  Unnamed: 0    GLY  \
# 0                 0           0  GLY10
# 1                 1           1  GLY10
# 2                 2           2  GLY10
# 3                 3           3  GLY10
# 4                 4           4  GLY10
# ...             ...         ...    ...
# 23630         23630       23630  GLY80
# 23631         23631       23631  GLY80
# 23632         23632       23632  GLY80
# 23633         23633       23633  GLY80
# 23634         23634       23634  GLY80
#
#                                            folderName  \
# 0      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 1      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 2      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 3      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 4      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# ...                                               ...
# 23630  GLY80P100_D0_30HZ_20XINF_UWELL_20221228_135442
# ...

# %%
DF['pathimg'].tolist()
# Out:
# ['/media/SSD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt39_msd1.32.png',
#  '/media/SSD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt12_msd0.42.png',
#  '/media/SSD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt398_msd14.37.png',
#  '/media/SSD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt31_msd1.04.png',
#  '/media/SSD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt100_msd3.53.png',
#  '/media/SSD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt630_msd22.67.png',
# ...

# %%
##pth FFT in 29 ==> /media/tohn/HDD/rheology2023 
DF['pathimg'] = DF['pathimg'].str.replace('/media/SSD','/media/tohn/HDD')
DF
# Out:
#        Unnamed: 0.1  Unnamed: 0    GLY  \
# 0                 0           0  GLY10
# 1                 1           1  GLY10
# 2                 2           2  GLY10
# 3                 3           3  GLY10
# 4                 4           4  GLY10
# ...             ...         ...    ...
# 23630         23630       23630  GLY80
# 23631         23631       23631  GLY80
# 23632         23632       23632  GLY80
# 23633         23633       23633  GLY80
# 23634         23634       23634  GLY80
#
#                                            folderName  \
# 0      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 1      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 2      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 3      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# 4      GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944
# ...                                               ...
# 23630  GLY80P100_D0_30HZ_20XINF_UWELL_20221228_135442
# ...

# %%
DF['pathimg'].tolist()
# Out:
# ['/media/tohn/HDD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt39_msd1.32.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt12_msd0.42.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt398_msd14.37.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt31_msd1.04.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_213944_idt100_msd3.53.png',
# ...

# %%
DF.to_csv('/media/tohn/HDD/rheology2023/filesMSDT_G/datasetMSDT_train_valid.csv')

# %%
## 2. Test set
test = pd.read_csv('/media/tohn/HDD/rheology2023/filesMSDT_G/MSDT_datatest.csv')
print(test.shape)
test.head()
# Out:
# (870, 8)
#    Unnamed: 0    GLY                                      folderName  \
# 0           0  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 1           1  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 2           2  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 3           3  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 4           4  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
#
#                                             fileName  \
# 0  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 1  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 2  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 3  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 4  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
#
#                                              pathimg  idt  MSDT subset
# 0  /media/SSD/rheology2023/Glycerol_FFT_test/GLY1...  158  5.63   test
# 1  /media/SSD/rheology2023/Glycerol_FFT_test/GLY1...   25  0.84   test
# ...

# %%
test['pathimg'].tolist()
# Out:
# ['/media/SSD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt158_msd5.63.png',
#  '/media/SSD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt25_msd0.84.png',
#  '/media/SSD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt7_msd0.25.png',
#  '/media/SSD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt125_msd4.45.png',
#  '/media/SSD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt19_msd0.63.png',
# ...

# %%
test['pathimg'] = test['pathimg'].str.replace('/media/SSD','/media/tohn/HDD')
test.head()
# Out:
#    Unnamed: 0    GLY                                      folderName  \
# 0           0  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 1           1  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 2           2  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 3           3  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
# 4           4  GLY10  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204
#
#                                             fileName  \
# 0  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 1  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 2  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 3  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
# 4  GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204...
#
#                                              pathimg  idt  MSDT subset
# 0  /media/tohn/HDD/rheology2023/Glycerol_FFT_test...  158  5.63   test
# 1  /media/tohn/HDD/rheology2023/Glycerol_FFT_test...   25  0.84   test
# ...

# %%
test['pathimg'].tolist()
# Out:
# ['/media/tohn/HDD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt158_msd5.63.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt25_msd0.84.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt7_msd0.25.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt125_msd4.45.png',
#  '/media/tohn/HDD/rheology2023/Glycerol_FFT_test/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204/FFT/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204_idt19_msd0.63.png',
# ...

# %%
test.to_csv('/media/tohn/HDD/rheology2023/filesMSDT_G/MSDT_datatest.csv')

# %% [markdown]
# --------------------------------------------------------------------------

# %% [markdown]
# ## 📂Check Data 4,000 Serises

# %%
df = pd.read_csv("/home/kannika/code/Rheology2023/GLY7Level/MSDTGLY7Level10fold_4000serise_datatrain_tSecond-10fold.csv")
print(df.shape)
df.head()
# Out:
# (20300, 10)
#    Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1    GLY  \
# 0             0           0             0  GLY10
# 1             1           1             1  GLY10
# 2             2           2             2  GLY10
# 3             3           3             3  GLY10
# 4             4           4             4  GLY10
#
#                                        folderName  \
# 0  GLY10P100_D0_30HZ_20XINF_UWELL_20221229_183559
# 1  GLY10P100_D0_30HZ_20XINF_UWELL_20221229_183559
# 2  GLY10P100_D0_30HZ_20XINF_UWELL_20221229_183559
# 3  GLY10P100_D0_30HZ_20XINF_UWELL_20221229_183559
# 4  GLY10P100_D0_30HZ_20XINF_UWELL_20221229_183559
#
#                                              pathimg  idt      MSDT      my_t  \
# 0  /media/tohn/HDD/rheology2023/Glycerol7Level400...    1  0.053300  0.052498
# 1  /media/tohn/HDD/rheology2023/Glycerol7Level400...    2  0.073000  0.071849
# 2  /media/tohn/HDD/rheology2023/Glycerol7Level400...    3  0.092598  0.091199
# ...

# %%
min(df["my_t"])
# Out:
# 0.052498082

# %%
max(df["my_t"])
# Out:
# 2.081139379
